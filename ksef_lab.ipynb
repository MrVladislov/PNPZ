# %% [markdown]
# <a href="https://colab.research.google.com/github/MrVladislov/PNPZ/blob/main/ksef_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
# !python -m pip install cryptography

# %%
# !python -c "import cryptography; print(cryptography.__version__)"
# Out:
# 43.0.3
